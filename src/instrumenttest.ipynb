# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import pyvisa
from termcolor import cprint

# %%
def testGPIB(device):
    device.query("*IDN?")
    time.sleep(0.01)
    print(device.read())
    time.sleep(0.01)
    return 0

# %%
try:                            # try for GPIB connection
    resource = pyvisa.ResourceManager()
    SR830 = resource.open_resource(resource.list_resources()[0])
    cprint(SR830,"green")
    if input()=="y":
        pass
    else:
        sys.exit()
    connection = "GPIB"
    
except:
    cprint("WARNING: no GPIB connection detected","blue",attrs=['bold'])
# Out:
# WARNING: no GPIB connection detected
